# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ebd_US-IL-031_relJan-2021.txt', delimiter = '\t')
len(df)
# Out:
# /Users/williambush/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,10,11,39,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 5326988

# %%
# Below error appeared when running len(df)
# /Users/williambush/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,10,11,39,43) have mixed types.Specify dtype option on import or set low_memory=False.
# has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(5)
# Out:
#                          GLOBAL UNIQUE IDENTIFIER     LAST EDITED DATE  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS175185879  2013-01-05 14:48:01
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS286908453  2014-12-25 09:52:30
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS348011232  2015-10-18 18:47:54
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS174975934  2013-01-03 08:47:16
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS174976035  2014-08-04 12:20:27
#
#    TAXONOMIC ORDER CATEGORY             COMMON NAME      SCIENTIFIC NAME  \
# 0             5280  species        Common Gallinule    Gallinula galeata
# 1            32772  species          Hooded Warbler    Setophaga citrina
# 2              225  species  Fulvous Whistling-Duck  Dendrocygna bicolor
# 3             5314     form           American Coot     Fulica americana
# 4             5083  species               King Rail       Rallus elegans
#
#          SUBSPECIES COMMON NAME       SUBSPECIES SCIENTIFIC NAME  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3  American Coot (Red-shielded)  Fulica americana (Red-shielded)
# 4                           NaN                              NaN
#
#   OBSERVATION COUNT BREEDING BIRD ATLAS CODE  ... NUMBER OBSERVERS  \
# 0                 X                      NaN  ...              1.0
# 1                 1                      NaN  ...              NaN
# 2                 1                      NaN  ...              NaN
# 3                 X                      NaN  ...              1.0
# 4                 X                      NaN  ...              1.0
#
#   ALL SPECIES REPORTED GROUP IDENTIFIER HAS MEDIA APPROVED REVIEWED REASON  \
# 0                    0              NaN         0        1        1    NaN
# 1                    0              NaN         0        1        0    NaN
# 2                    0              NaN         0        1        1    NaN
# 3                    0              NaN         0        1        0    NaN
# 4                    0              NaN         0        1        1    NaN
#
#                                        TRIP COMMENTS  \
# 0  Cooke, Wells W. 1914. Distribution and Migrati...
# 1  Chapman, F.M. 1907. The Warblers of North Amer...
# 2  Entered from Dan Kassebaum's compilation of Il...
# 3  Cooke, Wells W. 1914. Distribution and Migrati...
# 4  Cooke, Wells W. 1914. Distribution and Migrati...
#
#                                     SPECIES COMMENTS  Unnamed: 46
# 0  specimen in the National Museum of Natural His...          NaN
# 1                                     Specimen taken          NaN
# 2  Specimen at the Chicago Academy of Sciences. C...          NaN
# 3                            Earliest spring arrival          NaN
# 4                            Earliest spring arrival          NaN
#
# [5 rows x 47 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# GLOBAL UNIQUE IDENTIFIER
# LAST EDITED DATE
# TAXONOMIC ORDER
# CATEGORY
# COMMON NAME
# SCIENTIFIC NAME
# SUBSPECIES COMMON NAME
# SUBSPECIES SCIENTIFIC NAME
# OBSERVATION COUNT
# BREEDING BIRD ATLAS CODE
# BREEDING BIRD ATLAS CATEGORY
# AGE/SEX
# COUNTRY
# COUNTRY CODE
# STATE
# STATE CODE
# COUNTY
# COUNTY CODE
# IBA CODE
# BCR CODE
# USFWS CODE
# ATLAS BLOCK
# LOCALITY
# LOCALITY ID
# LOCALITY TYPE
# LATITUDE
# LONGITUDE
# OBSERVATION DATE
# TIME OBSERVATIONS STARTED
# OBSERVER ID
# SAMPLING EVENT IDENTIFIER
# PROTOCOL TYPE
# PROTOCOL CODE
# PROJECT CODE
# DURATION MINUTES
# EFFORT DISTANCE KM
# EFFORT AREA HA
# NUMBER OBSERVERS
# ALL SPECIES REPORTED
# GROUP IDENTIFIER
# HAS MEDIA
# APPROVED
# REVIEWED
# REASON
# TRIP COMMENTS
# SPECIES COMMENTS
# Unnamed: 46
# OBSERVATION COUNT INT

# %%
len(df[df["SCIENTIFIC NAME"] == "Falco sparverius"])
# 19535 observations of Falco sparverius (American Kestrel)

len(df[df["SCIENTIFIC NAME"] == "Turdus migratorius"])
# 188074 observatinos of Turdus migratorius (American Robin)
# Out:
# 188074

# %%
df_species_count = df.groupby("COMMON NAME", as_index=False).count()
df_species_count.head(5)
# Out:
#                                          COMMON NAME  \
# 0                                 Acadian Flycatcher
# 1                                Acanthis/Spinus sp.
# 2                                      Accipiter sp.
# 3                              African Collared-Dove
# 4  African Collared-Dove (Domestic type or Ringed...
#
#    GLOBAL UNIQUE IDENTIFIER  LAST EDITED DATE  TAXONOMIC ORDER  CATEGORY  \
# 0                       797               797              797       797
# 1                        41                41               41        41
# 2                       480               480              480       480
# 3                         1                 1                1         1
# 4                        34                34               34        34
#
#    SCIENTIFIC NAME  SUBSPECIES COMMON NAME  SUBSPECIES SCIENTIFIC NAME  \
# 0              797                       0                           0
# 1               41                       0                           0
# 2              480                       0                           0
# 3                1                       0                           0
# 4               34                       0                           0
#
#    OBSERVATION COUNT  BREEDING BIRD ATLAS CODE  ...  NUMBER OBSERVERS  \
# 0                797                        37  ...               742
# 1                 41                         0  ...                40
# 2                480                         7  ...               476
# 3                  1                         0  ...                 1
# 4                 34                         0  ...                33
#
#    ALL SPECIES REPORTED  GROUP IDENTIFIER  HAS MEDIA  APPROVED  REVIEWED  \
# 0                   797               192        797       797       797
# 1                    41                 4         41        41        41
# 2                   480               122        480       480       480
# 3                     1                 0          1         1         1
# 4                    34                 0         34        34        34
#
#    REASON  TRIP COMMENTS  SPECIES COMMENTS  Unnamed: 46
# 0       0            226               272            0
# 1       0             11                10            0
# 2       0            151               144            0
# 3       0              0                 1            0
# 4       0              1                34            0
#
# [5 rows x 47 columns]

# %%
df["OBSERVATION COUNT INT"] = df["OBSERVATION COUNT"]

df["OBSERVATION COUNT INT"].replace(to_replace="X", value=0, inplace=True)

df["OBSERVATION COUNT INT"] = df["OBSERVATION COUNT INT"].astype(int)

# %%
df_obs_count = df.groupby("COMMON NAME", as_index=False).sum()[["COMMON NAME", "OBSERVATION COUNT INT"]].sort_values("OBSERVATION COUNT INT", ascending=False).reset_index(drop=True)
df_obs_count
# Out:
#                        COMMON NAME  OBSERVATION COUNT INT
# 0                     Canada Goose                5949134
# 1                 Ring-billed Gull                5109893
# 2                European Starling                3032227
# 3                   American Robin                2175518
# 4                    House Sparrow                1959096
# ..                             ...                    ...
# 562  Grasshopper/Henslow's Sparrow                      0
# 563                Grace's Warbler                      0
# 564         Williamson's Sapsucker                      0
# 565                    Ross's Gull                      0
# 566         Sharp-tailed Sandpiper                      0
#
# [567 rows x 2 columns]

# %%
df_219 = df[df["OBSERVATION COUNT INT"] == 219]
df_219[["OBSERVER ID", "OBSERVATION DATE"]]
# Out:
#          OBSERVER ID OBSERVATION DATE
# 161001    obsr779677       1981-08-02
# 292789     obsr95523       1994-04-05
# 311543     obsr95523       1995-01-17
# 311556     obsr95523       1995-01-17
# 339658     obsr95523       1995-09-06
# 371289     obsr95523       1996-07-07
# 406203     obsr95523       1997-09-10
# 406228     obsr95523       1997-09-10
# 541791    obsr349129       2001-05-07
# 566000     obsr95523       2002-03-12
# 740220     obsr34033       2005-10-08
# 740361     obsr11027       2005-11-17
# 768346     obsr95523       2006-05-24
# 1034616   obsr142929       2009-12-26
# 1142192   obsr177921       2010-11-20
# 1422033   obsr142929       2012-07-19
# 1478365   obsr157804       2012-10-11
# 1502822   obsr142929       2012-12-20
# 1525350   obsr211276       2013-02-04
# 1753405   obsr445736       2013-11-25
# 1781418    obsr95523       2014-02-23
# 1781481    obsr95523       2014-02-23
# 1995180    obsr95523       2014-09-26
# 1995310    obsr95523       2014-09-26
# 2056200    obsr95523       2014-12-17
# 2190213   obsr261364       2015-05-14
# 2396196    obsr95523       2015-12-25
# 2396456   obsr106714       2015-12-25
# 2684198   obsr261364       2016-07-22
# 2684301   obsr652936       2016-07-22
# 2707121    obsr27185       2016-08-14
# 2736593   obsr106714       2016-09-20
# 2805400    obsr27185       2017-01-06
# 3131332   obsr211276       2017-08-07
# 3244367   obsr261364       2017-11-25
# 3273298   obsr211276       2018-01-19
# 3405172   obsr211276       2018-04-02
# 3685246   obsr811804       2018-08-18
# 5189781   obsr108577       2020-10-08
# 5263598  obsr1119761       2020-12-31
# 5298253    obsr92042       2021-01-10

# %%
# all of my observations from cook county
# my observer id is obsr1119761

df_wb = df[df["OBSERVER ID"] == "obsr1119761"]
df_wb
# Out:
#                                 GLOBAL UNIQUE IDENTIFIER  \
# 4676745   URN:CornellLabOfOrnithology:EBIRD:OBS976841340
# 4682946   URN:CornellLabOfOrnithology:EBIRD:OBS976139750
# 4684200   URN:CornellLabOfOrnithology:EBIRD:OBS976841576
# 4690079   URN:CornellLabOfOrnithology:EBIRD:OBS976839024
# 4702435   URN:CornellLabOfOrnithology:EBIRD:OBS976839839
# ...                                                  ...
# 5321230  URN:CornellLabOfOrnithology:EBIRD:OBS1053281704
# 5322553  URN:CornellLabOfOrnithology:EBIRD:OBS1053074362
# 5322830  URN:CornellLabOfOrnithology:EBIRD:OBS1048955485
# 5322865  URN:CornellLabOfOrnithology:EBIRD:OBS1061915149
# 5323899  URN:CornellLabOfOrnithology:EBIRD:OBS1061915148
#
#                    LAST EDITED DATE  TAXONOMIC ORDER  CATEGORY  \
# 4676745         2020-10-01 18:58:58            20638   species
# 4682946         2020-10-01 18:58:58            31382   species
# 4684200         2020-10-01 18:58:58            32773   species
# 4690079         2020-10-01 18:58:58            27462   species
# 4702435         2020-10-01 18:58:58            32682   species
# ...                             ...              ...       ...
# 5321230  2021-01-17 00:29:30.281525              576   species
# 5322553  2021-01-17 00:29:30.281525             6263   species
# 5322830  2021-01-10 17:34:05.020786             6263   species
# 5322865  2021-01-29 18:03:11.479193             6263   species
# 5323899  2021-01-29 18:03:11.478351             1813  domestic
#
#                      COMMON NAME        SCIENTIFIC NAME  \
# 4676745            American Crow  Corvus brachyrhynchos
# 4682946       American Goldfinch         Spinus tristis
# 4684200        American Redstart    Setophaga ruticilla
# 4690079           American Robin     Turdus migratorius
# 4702435  Black-and-white Warbler        Mniotilta varia
# ...                          ...                    ...
# 5321230                  Redhead       Aythya americana
# 5322553         Ring-billed Gull     Larus delawarensis
# 5322830         Ring-billed Gull     Larus delawarensis
# 5322865         Ring-billed Gull     Larus delawarensis
# 5323899              Rock Pigeon          Columba livia
#
#              SUBSPECIES COMMON NAME    SUBSPECIES SCIENTIFIC NAME  \
# 4676745                         NaN                           NaN
# 4682946                         NaN                           NaN
# 4684200                         NaN                           NaN
# 4690079                         NaN                           NaN
# 4702435                         NaN                           NaN
# ...                             ...                           ...
# 5321230                         NaN                           NaN
# 5322553                         NaN                           NaN
# 5322830                         NaN                           NaN
# 5322865                         NaN                           NaN
# 5323899  Rock Pigeon (Feral Pigeon)  Columba livia (Feral Pigeon)
#
#         OBSERVATION COUNT BREEDING BIRD ATLAS CODE  ... ALL SPECIES REPORTED  \
# 4676745                 1                      NaN  ...                    0
# 4682946                 1                      NaN  ...                    0
# 4684200                 1                      NaN  ...                    0
# 4690079                 1                      NaN  ...                    0
# 4702435                 1                      NaN  ...                    0
# ...                   ...                      ...  ...                  ...
# 5321230                 2                      NaN  ...                    1
# 5322553                10                      NaN  ...                    1
# 5322830                11                      NaN  ...                    1
# 5322865                 9                      NaN  ...                    1
# 5323899                30                      NaN  ...                    1
#
#         GROUP IDENTIFIER HAS MEDIA APPROVED REVIEWED REASON  \
# 4676745              NaN         0        1        0    NaN
# 4682946              NaN         0        1        0    NaN
# 4684200              NaN         0        1        0    NaN
# 4690079              NaN         0        1        0    NaN
# 4702435              NaN         0        1        0    NaN
# ...                  ...       ...      ...      ...    ...
# 5321230              NaN         0        1        0    NaN
# 5322553              NaN         0        1        0    NaN
# 5322830              NaN         0        1        0    NaN
# 5322865              NaN         0        1        0    NaN
# 5323899              NaN         0        1        0    NaN
#
#                           TRIP COMMENTS SPECIES COMMENTS Unnamed: 46  \
# 4676745                             NaN              NaN         NaN
# 4682946                             NaN              NaN         NaN
# 4684200                             NaN              NaN         NaN
# 4690079                             NaN              NaN         NaN
# 4702435                             NaN              NaN         NaN
# ...                                 ...              ...         ...
# 5321230  36F, overcast, wind WNW 10 mph              NaN         NaN
# 5322553  36F, overcast, wind WNW 10 mph              NaN         NaN
# 5322830                    28F, cloudy.              NaN         NaN
# 5322865                             NaN              NaN         NaN
# 5323899                             NaN      Approximate         NaN
#
#          OBSERVATION COUNT INT
# 4676745                      1
# 4682946                      1
# 4684200                      1
# 4690079                      1
# 4702435                      1
# ...                        ...
# 5321230                      2
# 5322553                     10
# 5322830                     11
# 5322865                      9
# 5323899                     30
#
# [439 rows x 48 columns]

# %%
# trend of observations per day in 2020

daily_obs = df.groupby("OBSERVATION DATE", as_index=False).sum()[["OBSERVATION DATE", "OBSERVATION COUNT INT"]]
daily_obs_18to20 = daily_obs[(daily_obs["OBSERVATION DATE"] > "2017-12-31") & (daily_obs["OBSERVATION DATE"] < "2021-01-01")]
daily_obs_18to20

daily_obs_20 =  daily_obs[(daily_obs["OBSERVATION DATE"] > "2019-12-31") & (daily_obs["OBSERVATION DATE"] < "2021-01-01")]

# %%
obs_date = list(daily_obs_18to20["OBSERVATION DATE"])
obs_count = list(daily_obs_18to20["OBSERVATION COUNT INT"])

plt.plot(obs_date, obs_count)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
obs_date_20 = list(daily_obs_20["OBSERVATION DATE"])
obs_count_20 = list(daily_obs_20["OBSERVATION COUNT INT"])

plt.plot(obs_date_20, obs_count_20)
plt.show()

# %%
# INSIGHTS:
    
# distribution of average observations per species per month or year
